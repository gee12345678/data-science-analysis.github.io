# %% [markdown]
# <a href="https://colab.research.google.com/github/gee12345678/data-science-analysis.github.io/blob/main/Superstore_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Sample - Superstore.csv', encoding='ISO-8859-1')


df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# Convert date columns to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# Remove duplicates (if any)
df = df.drop_duplicates()

# Preview cleaned data
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# Check for missing values
missing = df.isnull().sum()
print("Missing values per column:\n", missing)

# If missing values existed, you could fill or drop them:
# df = df.dropna()  # drop missing rows
# df['Column'] = df['Column'].fillna(value)  # fill specific column

# Since this dataset has no missing values, no changes needed
# Out:
# Missing values per column:
#  Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
# Describe numeric columns
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  9994.000000                           9994
# mean   4997.500000  2016-04-30 00:07:12.259355648
# min       1.000000            2014-01-03 00:00:00
# 25%    2499.250000            2015-05-23 00:00:00
# 50%    4997.500000            2016-06-26 00:00:00
# 75%    7495.750000            2017-05-14 00:00:00
# max    9994.000000            2017-12-30 00:00:00
# std    2885.163629                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9994   9994.000000   9994.000000  9994.000000
# mean   2016-05-03 23:06:58.571142912  55190.379428    229.858001     3.789574
# min              2014-01-07 00:00:00   1040.000000      0.444000     1.000000
# 25%              2015-05-27 00:00:00  23223.000000     17.280000     2.000000
# 50%              2016-06-29 00:00:00  56430.500000     54.490000     3.000000
# ...

# %%
# Total sales and profit by category
plt.figure(figsize=(10,5))
sns.barplot(data=df, x='Category', y='Sales', estimator=sum)
plt.title('Total Sales by Category')
plt.show()

plt.figure(figsize=(10,5))
sns.barplot(data=df, x='Category', y='Profit', estimator=sum)
plt.title('Total Profit by Category')
plt.show()

# %%
# Boxplot for Sales
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='Category', y='Sales')
plt.title('Sales Outliers by Category')
plt.show()

# Boxplot for Profit
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='Category', y='Profit')
plt.title('Profit Outliers by Category')
plt.show()

# %%
from scipy import stats
import numpy as np

# Filter based on Z-score
z_scores = np.abs(stats.zscore(df[['Sales', 'Profit']]))
df_clean = df[(z_scores < 3).all(axis=1)]

print(f"Original rows: {len(df)}, Cleaned rows: {len(df_clean)}")
# Out:
# Original rows: 9994, Cleaned rows: 9829

# %%
# Total profit by region and category
grouped = df.groupby(['Region', 'Category'])[['Sales', 'Profit']].sum().reset_index()
print(grouped)
# Out:
#      Region         Category        Sales      Profit
# 0   Central        Furniture  163797.1638  -2871.0494
# 1   Central  Office Supplies  167026.4150   8879.9799
# 2   Central       Technology  170416.3120  33697.4320
# 3      East        Furniture  208291.2040   3046.1658
# 4      East  Office Supplies  205516.0550  41014.5791
# 5      East       Technology  264973.9810  47462.0351
# 6     South        Furniture  117298.6840   6771.2061
# 7     South  Office Supplies  125651.3130  19986.3928
# 8     South       Technology  148771.9080  19991.8314
# 9      West        Furniture  252612.7435  11504.9503
# 10     West  Office Supplies  220853.2490  52609.8490
# 11     West       Technology  251991.8320  44303.6496

# %%
# Aggregate by order date
time_data = df_clean.groupby('Order Date')[['Sales', 'Profit']].sum().reset_index()

# Line plot for Sales and Profit over time
plt.figure(figsize=(14, 6))
plt.plot(time_data['Order Date'], time_data['Sales'], label='Sales')
plt.plot(time_data['Order Date'], time_data['Profit'], label='Profit')
plt.title('Sales and Profit Over Time')
plt.xlabel('Date')
plt.ylabel('Amount')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Create month-year column
df_clean['Month'] = df_clean['Order Date'].dt.to_period('M')

# Monthly summary
monthly_data = df_clean.groupby('Month')[['Sales', 'Profit']].sum().reset_index()
monthly_data['Month'] = monthly_data['Month'].astype(str)

# Plot
plt.figure(figsize=(14, 6))
sns.lineplot(data=monthly_data, x='Month', y='Sales', label='Sales')
sns.lineplot(data=monthly_data, x='Month', y='Profit', label='Profit')
plt.xticks(rotation=45)
plt.title('Monthly Sales and Profit Trend')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\moe\AppData\Local\Temp\ipykernel_10824\3481091085.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Month'] = df_clean['Order Date'].dt.to_period('M')
# C:\Users\moe\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\moe\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Top sub-categories by total sales
top_sales = df_clean.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False).head(10)
top_profit = df_clean.groupby('Sub-Category')['Profit'].sum().sort_values(ascending=False).head(10)

# Plot
plt.figure(figsize=(12,5))
top_sales.plot(kind='bar', title='Top 10 Sub-Categories by Sales', color='skyblue')
plt.ylabel('Total Sales')
plt.show()

plt.figure(figsize=(12,5))
top_profit.plot(kind='bar', title='Top 10 Sub-Categories by Profit', color='lightgreen')
plt.ylabel('Total Profit')
plt.show()

# %%
# Correlation matrix
correlation = df_clean[['Sales', 'Quantity', 'Discount', 'Profit']].corr()

# Heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
# Create a pivot table
pivot_table = pd.pivot_table(
    df_clean,
    values=['Sales', 'Profit'],
    index='Region',
    columns='Category',
    aggfunc='sum',
    margins=True,
    margins_name='Total'
)

# Display the pivot table
pivot_table
# Out:
#               Profit                                                 Sales  \
# Category   Furniture Office Supplies  Technology        Total    Furniture
# Region
# Central   -4589.7248       9661.8117  21076.1423   26148.2292  147387.9482
# East       2553.0357      34109.4467  20844.4963   57506.9787  170461.3850
# South      8589.3442      17443.7936  15976.5437   42009.6815   96483.8660
# West      10961.9873      44923.5614  29794.7411   85680.2898  224552.0715
# Total     17514.6424     106138.6134  87691.9234  211345.1792  638885.2707
#
#
# Category Office Supplies  Technology         Total
# Region
# Central       112325.605  118871.946  3.785855e+05
# East          169485.503  151990.789  4.919377e+05
# South          96687.866   80741.041  2.739128e+05
# West          184217.043  176606.695  5.853758e+05
# Total         562716.017  528210.471  1.729812e+06

# %%
df_clean.to_csv('Cleaned_Superstore.csv', index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap

# Set the style
plt.style.use('ggplot')
sns.set_style("whitegrid")

# Create the data for each visualization

# Chart 1: Sum of Sales by Sub-Category (Bar chart)
subcategories = ['Phones', 'Chairs', 'Storage', 'Tables', 'Accessories',
                'Binders', 'Appliances', 'Furnishings', 'Bookcases', 'Paper',
                'Copiers', 'Machines', 'Art', 'Supplies', 'Envelopes', 'Labels', 'Fasteners']
subcategory_sales = [290000, 280000, 220000, 170000, 150000,
                    95000, 90000, 90000, 85000, 75000,
                    40000, 38000, 25000, 15000, 15000, 12000, 2000]

# Chart 2: Sum of Sales by Region (Pie chart)
regions = ['West', 'East', 'Central', 'South']
region_sales = [585380, 491940, 378590, 273910]
region_percentages = [33.84, 28.44, 21.89, 15.83]

# Chart 3: Sum of Sales by Year (Area chart)
years = [2014, 2015, 2016, 2017]
yearly_sales = [355000, 377000, 447000, 549683.08]

# Chart 4: Sum of Sales by Category (Horizontal bar chart)
categories = ['Furniture', 'Office Supplies', 'Technology']
category_sales = [638885.27, 560000, 530000]

# Chart 5: Sum of Profit by Segment (Donut chart)
segments = ['Consumer', 'Corporate', 'Home Office']
segment_profits = [105570, 64610, 41170]
segment_percentages = [49.95, 30.57, 19.48]

# Create a figure with subplots
fig = plt.figure(figsize=(20, 25))

# 1. Sum of Sales by Sub-Category
ax1 = fig.add_subplot(5, 1, 1)
maroon_color = '#800000'
bars = ax1.bar(subcategories, subcategory_sales, color=maroon_color)
ax1.set_title('SUM OF SALES BY SUB-CATEGORY', fontsize=14, loc='left')
ax1.set_xlabel('Sub-Category', fontsize=12)
ax1.set_ylabel('Sum of Sales', fontsize=12)
ax1.tick_params(axis='x', rotation=45)
ax1.set_ylim(0, 300000)
ax1.set_yticks([0, 50000, 100000, 150000, 200000, 250000, 300000])
ax1.set_yticklabels(['0K', '50K', '100K', '150K', '200K', '250K', '300K'])

# 2. Sum of Sales by Region
ax2 = fig.add_subplot(5, 1, 2)
colors = ['#6a0dad', '#000080', '#1e90ff', '#ff7f50']
explode = (0.01, 0.01, 0.01, 0.01)
wedges, texts, autotexts = ax2.pie(region_sales, explode=explode, labels=None,
                                   autopct='%1.2f%%', colors=colors,
                                   startangle=90, pctdistance=0.85)
# Add annotations with sales values
for i, (pct, sales) in enumerate(zip(region_percentages, region_sales)):
    ax2.annotate(f"{sales/1000:.2f}K ({pct}%)",
                xy=(0.5, 0.5),
                xytext=(0.7*np.cos(np.radians(90-i*90-45)), 0.7*np.sin(np.radians(90-i*90-45))),
                textcoords='axes fraction',
                ha='center', va='center')

# Add legend with custom handles
handles = [plt.Rectangle((0,0),1,1, color=colors[i]) for i in range(len(regions))]
legend = ax2.legend(handles, regions, loc="center right", title="Region")
ax2.set_title('SUM OF SALES BY REGION', fontsize=14, loc='left')

# 3. Sum of Sales by Year
ax3 = fig.add_subplot(5, 1, 3)
ax3.plot(years, yearly_sales, 'bo-', linewidth=2, markersize=8)
ax3.fill_between(years, yearly_sales, alpha=0.3, color='#ff7f50')
ax3.set_title('SUM OF SALES BY YEAR', fontsize=14, loc='left')
ax3.set_xlabel('Year', fontsize=12)
ax3.set_ylabel('Sum of Sales', fontsize=12)
ax3.set_ylim(350000, 560000)
ax3.set_yticks([350000, 400000, 450000, 500000, 550000])
ax3.set_yticklabels(['350K', '400K', '450K', '500K', '550K'])

# Annotation for 2017
ax3.annotate('2017\nSum of Sales: 549,683.08',
            xy=(2017, 549683.08), xytext=(2017, 549683.08 + 8000),
            arrowprops=dict(arrowstyle='->', color='black'), ha='center')

# 4. Sum of Sales by Category
ax4 = fig.add_subplot(5, 1, 4)
bars = ax4.barh(categories, category_sales, color='#6a0dad')
ax4.set_title('SUM OF SALES BY CATEGORY', fontsize=14, loc='left')
ax4.set_xlabel('Sum of Sales', fontsize=12)
ax4.set_ylabel('Category', fontsize=12)
ax4.set_xlim(0, 700000)
ax4.set_xticks([0, 100000, 200000, 300000, 400000, 500000, 600000, 700000])
ax4.set_xticklabels(['0.0M', '0.1M', '0.2M', '0.3M', '0.4M', '0.5M', '0.6M', '0.7M'])

# Add value labels to the end of each bar
for i, v in enumerate(category_sales):
    if i == 0:  # For Furniture - add annotation with tooltip
        ax4.text(v + 10000, i, f'{v/1000000:.2f}M', va='center')
        ax4.annotate('Category: Furniture\nSum of Sales: 638,885.27',
                   xy=(v, i), xytext=(v - 100000, i + 0.2),
                   bbox=dict(boxstyle='round,pad=0.5', fc='white', alpha=0.7),
                   arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.3'))
    else:
        ax4.text(v + 10000, i, f'{v/1000000:.2f}M', va='center')

# 5. Sum of Profit by Segment
ax5 = fig.add_subplot(5, 1, 5)
colors = ['#6a0dad', '#c71585', '#800000']
# Create a donut chart (pie chart with a hole in the middle)
wedges, texts = ax5.pie(segment_profits, colors=colors, startangle=90,
                      wedgeprops=dict(width=0.5))

# Add annotations for each segment
for i, (pct, profit) in enumerate(zip(segment_percentages, segment_profits)):
    angle = 90 - 360 * (sum(segment_profits[:i]) + segment_profits[i]/2) / sum(segment_profits)
    x = 0.7 * np.cos(np.radians(angle))
    y = 0.7 * np.sin(np.radians(angle))
    ax5.text(x, y, f"{profit/1000:.2f}K\n({pct:.2f}%)", ha='center', va='center')

# Add legend with custom handles
handles = [plt.Rectangle((0,0),1,1, color=colors[i]) for i in range(len(segments))]
legend = ax5.legend(handles, segments, loc="center right", title="Segment")
ax5.set_title('SUM OF PROFIT BY SEGMENT', fontsize=14, loc='left')

plt.tight_layout(pad=3.0)
plt.show()

# Alternatively, you could create each visualization separately
# Here's an example of creating just the first chart (Sum of Sales by Sub-Category)

def create_subcategory_chart():
    plt.figure(figsize=(12, 8))
    maroon_color = '#800000'
    plt.bar(subcategories, subcategory_sales, color=maroon_color)
    plt.title('SUM OF SALES BY SUB-CATEGORY', fontsize=14, loc='left')
    plt.xlabel('Sub-Category', fontsize=12)
    plt.ylabel('Sum of Sales', fontsize=12)
    plt.xticks(rotation=45)
    plt.ylim(0, 300000)
    plt.yticks([0, 50000, 100000, 150000, 200000, 250000, 300000],
              ['0K', '50K', '100K', '150K', '200K', '250K', '300K'])
    plt.tight_layout()
    plt.show()

# Uncomment to show individual charts
# create_subcategory_chart()
